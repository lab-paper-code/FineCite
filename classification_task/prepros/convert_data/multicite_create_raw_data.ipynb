# %%
import json
import pandas as pd
import random
import re
from sklearn.model_selection import train_test_split
import nltk
import math
import numpy as np
import os

# %%
with open('/raid/deallab/CCE_Data/raw_data/multicite/full_raw.json', 'r') as f:
    full_dataset = json.load(f)

# %%
sent_id_lookup = {}
for i , key in enumerate(full_dataset):
    doc = full_dataset[key]['x']
    staged_lookup = []
    for sent in doc:
        staged_lookup.append(sent['sent_id'])
    staged_lookup.sort(key=lambda x: int(x.split('-')[-1]))
    sent_id_lookup[key] = staged_lookup

# %%
#helper 
def clean_sentence(sent):
    return re.sub(r'<span style.*>', ' #AUTHOR_TAG ', sent)

# %%
sent_lookup = {}
sent_structure = {}
for i , key in enumerate(full_dataset):
    doc = {}
    for sent in full_dataset[key]['x']:
        doc[sent['sent_id']] = clean_sentence(sent['text'])
    ids = sent_id_lookup[key]
    staged_lookup = {}
    staged_structure = {}
    section_id = 0
    section = []
    for id in ids:
        text = doc[id]
        if text[:5] == '-----':
            continue
        elif text[:2] + text[-2:] == '****':
            staged_structure[section_id] = section
            section_id += 1
            section = []
        else:
            staged_lookup[id] = {'text': text, 'section_id': section_id}
            section.append(text)
    staged_structure[section_id] = section
    sent_lookup[key] = staged_lookup
    sent_structure[key] = staged_structure

# %%
train, test = train_test_split(list(full_dataset.keys()), test_size=0.2, random_state=99)

# %%
INTENT_TOKEN_MAPPING = {'@BACK@': 0, '@MOT@': 1, '@FUT@':2, '@SIM@':3, '@DIF@':4, '@USE@':5, '@EXT@':6, '@UNSURE@':7}
COLUMNS = ['unique_id','citing_id','citing_title','cited_title','cited_authors','section_title','cited_abstract_auto','citation_context','multicite_context','cite_context_paragraph','citation_class_label']

full_df = pd.DataFrame(columns=COLUMNS)

for dataset, name in [(train,'train'), (test,'test')]:
    df = pd.DataFrame(columns=COLUMNS)
    prefix = 'CC' if name == 'train' else 'CCT'
    counter = 0

    for i , key in enumerate(dataset):
        doc = full_dataset[key]['y']
        for intent in doc:
            intent_id = INTENT_TOKEN_MAPPING[intent]
            cite_sent = doc[intent]['cite_sentences']
            gold_cont = doc[intent]['gold_contexts']
            if(len(cite_sent) != len(gold_cont)): 
                print(f'there are not the same amount of gold contexts and citation sentences at document {key}, intent {intent}')
                continue
            for i, cit in enumerate(cite_sent):
                if cit not in sent_lookup[key].keys(): 
                    print(f'cant find sentence id {cit}')
                    continue
                text = sent_lookup[key][cit]['text']
                section_id = sent_lookup[key][cit]['section_id']
                multicite_cont = [sent_lookup[key][id]['text'] for id in gold_cont[i] if id in sent_lookup[key].keys()]
                df.loc[len(df)] = [f'{prefix}{counter}', cit, None, None, None, None, None, text, multicite_cont, sent_structure[key][section_id], intent_id ]
                counter += 1       
    df.to_csv(f'../data/multicite/{name}_raw.txt', sep='\t', index=False)   
    full_df = pd.concat([full_df, df])
# Out:
# there are not the same amount of gold contexts and citation sentences at document ABC_57e65909baf823ff00a9a10a64fffd_15, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_57e65909baf823ff00a9a10a64fffd_15, intent @SIM@
# there are not the same amount of gold contexts and citation sentences at document ABC_57e65909baf823ff00a9a10a64fffd_15, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_57e65909baf823ff00a9a10a64fffd_15, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_41de1ad534ca00b7a99260de7bb0b2_2, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_518d8a8395e38d9971bd51344cf1b8_5, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_920f2b94270c0711fcc19ad23dbb0d_6, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_920f2b94270c0711fcc19ad23dbb0d_6, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_920f2b94270c0711fcc19ad23dbb0d_6, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_920f2b94270c0711fcc19ad23dbb0d_6, intent @SIM@
# there are not the same amount of gold contexts and citation sentences at document ABC
intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_f24dde456e02fdb8e65799685275d2_3, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_a7f4154081f4045390e662c6e6f3ac_15, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_97f8d0af85eda3e453fc4fb00819f0_2, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_23119eff3cfd71370e8ad408fc75e1_15, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_684a637d08e8dbabddc1f1982f5393_1, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_684a637d08e8dbabddc1f1982f5393_1, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_7293ab5db16d3fe1fee48d45154697_19, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_5a2cd80d7c57e06a51457e53169b49_5, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_ff7bafb8f21118ca3c908603ef32d0_6, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_ff7bafb8f21118ca3c908603ef32d0_6, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_ff7bafb8f21118ca3c908603ef32d0_6, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_280affafa32147a63e7eeda8d5f763_30, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_280affafa32147a63e7eeda8d5f763_30, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_74db2b52e81969742f8f7e5681bd2b_26, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_5fa570cf5f37c7aae3b428a17de3e3_9, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_4adcc28c6d1906d74874b8fca371dc_15, intent @SIM@
# there are not the same amount of gold contexts and citation sentences at document ABC_2f3e2c81bed66fd020731b2475bb98_8, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_2f3e2c81bed66fd020731b2475bb98_8, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_2f3e2c81bed66fd020731b2475bb98_8, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_2f3e2c81bed66fd020731b2475bb98_8, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_2f3e2c81bed66fd020731b2475bb98_8, intent @SIM@
# there are not the same amount of gold contexts and citation sentences at document ABC_023a954d97b5d761b01f09bb242d19_38, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_00a2e4d0cacfb1fb7098bd324d960a_9, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_13091dd4d06e11957a5cb7785b92d4_5, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_13091dd4d06e11957a5cb7785b92d4_5, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_13091dd4d06e11957a5cb7785b92d4_5, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_13091dd4d06e11957a5cb7785b92d4_5, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_5b14e259a557aa3cbfcbd6265f04c8_1, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_5b14e259a557aa3cbfcbd6265f04c8_1, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_6da7dcbcb7f52f31ec23c8131d438d_32, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_1056d36c5ed22c7a34f6fe82b4962f_5, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_1056d36c5ed22c7a34f6fe82b4962f_5, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_6b1432f4aac35e6acd8ca8770fe484_2, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_6b1432f4aac35e6acd8ca8770fe484_2, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_6b1432f4aac35e6acd8ca8770fe484_2, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_3395c9ed8ad9f2d048bf8ebf950d16_6, intent @BACK@
# there are not the same amount of gold contexts and citation sentences at document ABC_3395c9ed8ad9f2d048bf8ebf950d16_6, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_24506b0aa7a859eb8744e390f9fb60_7, intent @MOT@
# there are not the same amount of gold contexts and citation sentences at document ABC_e5886e138ce8d84a48e44db3f3d6a1_5, intent @USE@
# there are not the same amount of gold contexts and citation sentences at document ABC_e5886e138ce8d84a48e44db3f3d6a1_5, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_52c52f6ce3663de49d5784630af1e7_8, intent @DIF@
# there are not the same amount of gold contexts and citation sentences at document ABC_52c52f6ce3663de49d5784630af1e7_8, intent @EXT@
# there are not the same amount of gold contexts and citation sentences at document ABC_f2ff155003d139b3677f746baf3807_5, intent @UNSURE@
# there are not the same amount of gold contexts and citation sentences at document ABC_f2b9a5633600cdf787111841bf9ce6_5, intent @BACK@
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 29
#      27             df.loc[len(df)] = [f'{prefix}{counter}', cit, None, None, None, None, None, text, multicite_cont, sent_structure[key][section_id], intent_id ]
#      28             counter += 1
# ---> 29 df.to_csv(f'../data/multicite/{name}_raw.txt', sep='\t', index=False)
#      30 full_df = pd.concat([full_df, df])
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/envs/lasse/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../data/multicite'

# %%
# calculate weights
count =full_df['citation_class_label'].groupby(full_df['citation_class_label']).agg(['count'])['count'].to_list()
[len(full_df) / (len(count) * c) for c in count]
# Out:
# [0.39627130681818185,
#  2.27178338762215,
#  17.88301282051282,
#  1.1386734693877552,
#  0.9527834699453552,
#  0.42179467795585124,
#  2.15258487654321,
#  4.603547854785479]
